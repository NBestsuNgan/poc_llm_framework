# %%
nb_parm='datalake/raw/text-csv/feed_name.csv'

# %%
import sys
import os, io

sys.path.append("/home/jovyan/notebooks")
from Framework import base_tools

# %%
base_tools.register_agent('ADK/adk_fuzzy_match_bot')
# Out:
# SOURCE_DIR : /tmp/ADK/adk_fuzzy_match_bot
# TARGET_DIR : /tmp/packaged_agent/ADK/adk_fuzzy_match_bot
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - setuptools >= 40.8.0
# * Getting build dependencies for sdist...
# running egg_info
# creating adk_fuzzy_match_bot.egg-info
# writing adk_fuzzy_match_bot.egg-info/PKG-INFO
# writing dependency_links to adk_fuzzy_match_bot.egg-info/dependency_links.txt
# writing requirements to adk_fuzzy_match_bot.egg-info/requires.txt
# writing top-level names to adk_fuzzy_match_bot.egg-info/top_level.txt
# writing manifest file 'adk_fuzzy_match_bot.egg-info/SOURCES.txt'
# reading manifest file 'adk_fuzzy_match_bot.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# writing manifest file 'adk_fuzzy_match_bot.egg-info/SOURCES.txt'
# * Building sdist...
# running sdist
# running egg_info
# writing adk_fuzzy_match_bot.egg-info/PKG-INFO
# writing dependency_links to adk_fuzzy_match_bot.egg-info/dependency_links.txt
# writing requirements to adk_fuzzy_match_bot.egg-info/requires.txt
# writing top-level names to adk_fuzzy_match_bot.egg-info/top_level.txt
# reading manifest file 'adk_fuzzy_match_bot.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# writing manifest file 'adk_fuzzy_match_bot.egg-info/SOURCES.txt'
# running check
# creating adk_fuzzy_match_bot-0.1.0
# creating adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot
# creating adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot.egg-info
# creating adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot/__pycache__
# creating adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot/baseknowledge
# creating adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot/tools
# creating adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot/tools/__pycache__
# copying files to adk_fuzzy_match_bot-0.1.0...
# copying MANIFEST.in -> adk_fuzzy_match_bot-0.1.0
# copying setup.py -> adk_fuzzy_match_bot-0.1.0
# copying adk_fuzzy_match_bot/__init__.py -> adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot
# copying adk_fuzzy_match_bot/agent.py -> adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot
# copying adk_fuzzy_match_bot/prompt.py -> adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot
# copying adk_fuzzy_match_bot.egg-info/PKG-INFO -> adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot.egg-info
# copying adk_fuzzy_match_bot.egg-info/SOURCES.txt -> adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot.egg-info
# copying adk_fuzzy_match_bot.egg-info/dependency_links.txt -> adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot.egg-info
# copying adk_fuzzy_match_bot.egg-info/requires.txt -> adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot.egg-info
# copying adk_fuzzy_match_bot.egg-info/top_level.txt -> adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot.egg-info
# copying adk_fuzzy_match_bot/__pycache__/__init__.cpython-311.pyc -> adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot/__pycache__
# copying adk_fuzzy_match_bot/__pycache__/agent.cpython-311.pyc -> adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot/__pycache__
# copying adk_fuzzy_match_bot/__pycache__/prompt.cpython-311.pyc -> adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot/__pycache__
# copying adk_fuzzy_match_bot/baseknowledge/__init__.py -> adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot/baseknowledge
# copying adk_fuzzy_match_bot/baseknowledge/data_source.csv -> adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot/baseknowledge
# copying adk_fuzzy_match_bot/tools/__init__.py -> adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot/tools
# copying adk_fuzzy_match_bot/tools/retrieve_knowledge.py -> adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot/tools
# copying adk_fuzzy_match_bot/tools/__pycache__/__init__.cpython-311.pyc -> adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot/tools/__pycache__
# copying adk_fuzzy_match_bot/tools/__pycache__/retrieve_knowledge.cpython-311.pyc -> adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot/tools/__pycache__
# copying adk_fuzzy_match_bot.egg-info/SOURCES.txt -> adk_fuzzy_match_bot-0.1.0/adk_fuzzy_match_bot.egg-info
# Writing adk_fuzzy_match_bot-0.1.0/setup.cfg
# Creating tar archive
# removing 'adk_fuzzy_match_bot-0.1.0' (and everything under it)
# warning: sdist: standard file not found: should have one of README, README.rst, README.txt, README.md
# * Building wheel from sdist
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - setuptools >= 40.8.0
# * Getting build dependencies for wheel...
# running egg_info
# writing adk_fuzzy_match_bot.egg-info/PKG-INFO
# writing dependency_links to adk_fuzzy_match_bot.egg-info/dependency_links.txt
# writing requirements to adk_fuzzy_match_bot.egg-info/requires.txt
# writing top-level names to adk_fuzzy_match_bot.egg-info/top_level.txt
# reading manifest file 'adk_fuzzy_match_bot.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# writing manifest file 'adk_fuzzy_match_bot.egg-info/SOURCES.txt'
# * Building wheel...
# running bdist_wheel
# running build
# running build_py
# creating build/lib/adk_fuzzy_match_bot
# copying adk_fuzzy_match_bot/__init__.py -> build/lib/adk_fuzzy_match_bot
# copying adk_fuzzy_match_bot/agent.py -> build/lib/adk_fuzzy_match_bot
# copying adk_fuzzy_match_bot/prompt.py -> build/lib/adk_fuzzy_match_bot
# creating build/lib/adk_fuzzy_match_bot/tools
# copying adk_fuzzy_match_bot/tools/__init__.py -> build/lib/adk_fuzzy_match_bot/tools
# copying adk_fuzzy_match_bot/tools/retrieve_knowledge.py -> build/lib/adk_fuzzy_match_bot/tools
# creating build/lib/adk_fuzzy_match_bot/baseknowledge
# copying adk_fuzzy_match_bot/baseknowledge/__init__.py -> build/lib/adk_fuzzy_match_bot/baseknowledge
# running egg_info
# writing adk_fuzzy_match_bot.egg-info/PKG-INFO
# writing dependency_links to adk_fuzzy_match_bot.egg-info/dependency_links.txt
# writing requirements to adk_fuzzy_match_bot.egg-info/requires.txt
# writing top-level names to adk_fuzzy_match_bot.egg-info/top_level.txt
# reading manifest file 'adk_fuzzy_match_bot.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# writing manifest file 'adk_fuzzy_match_bot.egg-info/SOURCES.txt'
# creating build/lib/adk_fuzzy_match_bot/__pycache__
# copying adk_fuzzy_match_bot/__pycache__/__init__.cpython-311.pyc -> build/lib/adk_fuzzy_match_bot/__pycache__
# copying adk_fuzzy_match_bot/__pycache__/agent.cpython-311.pyc -> build/lib/adk_fuzzy_match_bot/__pycache__
# copying adk_fuzzy_match_bot/__pycache__/prompt.cpython-311.pyc -> build/lib/adk_fuzzy_match_bot/__pycache__
# creating build/lib/adk_fuzzy_match_bot/tools/__pycache__
# copying adk_fuzzy_match_bot/tools/__pycache__/__init__.cpython-311.pyc -> build/lib/adk_fuzzy_match_bot/tools/__pycache__
# copying adk_fuzzy_match_bot/tools/__pycache__/retrieve_knowledge.cpython-311.pyc -> build/lib/adk_fuzzy_match_bot/tools/__pycache__
# copying adk_fuzzy_match_bot/baseknowledge/data_source.csv -> build/lib/adk_fuzzy_match_bot/baseknowledge
# installing to build/bdist.linux-x86_64/wheel
# running install
# /tmp/build-env-tkw9u_ox/lib/python3.11/site-packages/setuptools/command/build_py.py:212: _Warning: Package 'adk_fuzzy_match_bot.__pycache__' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'adk_fuzzy_match_bot.__pycache__' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'adk_fuzzy_match_bot.__pycache__' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'adk_fuzzy_match_bot.__pycache__' to be distributed and are
#         already explicitly excluding 'adk_fuzzy_match_bot.__pycache__' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /tmp/build-env-tkw9u_ox/lib/python3.11/site-packages/setuptools/command/build_py.py:212: _Warning: Package 'adk_fuzzy_match_bot.tools.__pycache__' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'adk_fuzzy_match_bot.tools.__pycache__' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'adk_fuzzy_match_bot.tools.__pycache__' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'adk_fuzzy_match_bot.tools.__pycache__' to be distributed and are
#         already explicitly excluding 'adk_fuzzy_match_bot.tools.__pycache__' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# running install_lib
# creating build/bdist.linux-x86_64/wheel
# creating build/bdist.linux-x86_64/wheel/adk_fuzzy_match_bot
# copying build/lib/adk_fuzzy_match_bot/__init__.py -> build/bdist.linux-x86_64/wheel/./adk_fuzzy_match_bot
# creating build/bdist.linux-x86_64/wheel/adk_fuzzy_match_bot/tools
# copying build/lib/adk_fuzzy_match_bot/tools/__init__.py -> build/bdist.linux-x86_64/wheel/./adk_fuzzy_match_bot/tools
# copying build/lib/adk_fuzzy_match_bot/tools/retrieve_knowledge.py -> build/bdist.linux-x86_64/wheel/./adk_fuzzy_match_bot/tools
# creating build/bdist.linux-x86_64/wheel/adk_fuzzy_match_bot/tools/__pycache__
# copying build/lib/adk_fuzzy_match_bot/tools/__pycache__/__init__.cpython-311.pyc -> build/bdist.linux-x86_64/wheel/./adk_fuzzy_match_bot/tools/__pycache__
# copying build/lib/adk_fuzzy_match_bot/tools/__pycache__/retrieve_knowledge.cpython-311.pyc -> build/bdist.linux-x86_64/wheel/./adk_fuzzy_match_bot/tools/__pycache__
# copying build/lib/adk_fuzzy_match_bot/agent.py -> build/bdist.linux-x86_64/wheel/./adk_fuzzy_match_bot
# copying build/lib/adk_fuzzy_match_bot/prompt.py -> build/bdist.linux-x86_64/wheel/./adk_fuzzy_match_bot
# creating build/bdist.linux-x86_64/wheel/adk_fuzzy_match_bot/__pycache__
# copying build/lib/adk_fuzzy_match_bot/__pycache__/__init__.cpython-311.pyc -> build/bdist.linux-x86_64/wheel/./adk_fuzzy_match_bot/__pycache__
# copying build/lib/adk_fuzzy_match_bot/__pycache__/agent.cpython-311.pyc -> build/bdist.linux-x86_64/wheel/./adk_fuzzy_match_bot/__pycache__
# copying build/lib/adk_fuzzy_match_bot/__pycache__/prompt.cpython-311.pyc -> build/bdist.linux-x86_64/wheel/./adk_fuzzy_match_bot/__pycache__
# creating build/bdist.linux-x86_64/wheel/adk_fuzzy_match_bot/baseknowledge
# copying build/lib/adk_fuzzy_match_bot/baseknowledge/__init__.py -> build/bdist.linux-x86_64/wheel/./adk_fuzzy_match_bot/baseknowledge
# copying build/lib/adk_fuzzy_match_bot/baseknowledge/data_source.csv -> build/bdist.linux-x86_64/wheel/./adk_fuzzy_match_bot/baseknowledge
# running install_egg_info
# Copying adk_fuzzy_match_bot.egg-info to build/bdist.linux-x86_64/wheel/./adk_fuzzy_match_bot-0.1.0-py3.11.egg-info
# running install_scripts
# creating build/bdist.linux-x86_64/wheel/adk_fuzzy_match_bot-0.1.0.dist-info/WHEEL
# creating '/tmp/packaged_agent/ADK/adk_fuzzy_match_bot/dist/.tmp-w_cvxco7/adk_fuzzy_match_bot-0.1.0-py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
# adding 'adk_fuzzy_match_bot/__init__.py'
# adding 'adk_fuzzy_match_bot/agent.py'
# adding 'adk_fuzzy_match_bot/prompt.py'
# adding 'adk_fuzzy_match_bot/__pycache__/__init__.cpython-311.pyc'
# adding 'adk_fuzzy_match_bot/__pycache__/agent.cpython-311.pyc'
# adding 'adk_fuzzy_match_bot/__pycache__/prompt.cpython-311.pyc'
# adding 'adk_fuzzy_match_bot/baseknowledge/__init__.py'
# adding 'adk_fuzzy_match_bot/baseknowledge/data_source.csv'
# adding 'adk_fuzzy_match_bot/tools/__init__.py'
# adding 'adk_fuzzy_match_bot/tools/retrieve_knowledge.py'
# adding 'adk_fuzzy_match_bot/tools/__pycache__/__init__.cpython-311.pyc'
# adding 'adk_fuzzy_match_bot/tools/__pycache__/retrieve_knowledge.cpython-311.pyc'
# adding 'adk_fuzzy_match_bot-0.1.0.dist-info/METADATA'
# adding 'adk_fuzzy_match_bot-0.1.0.dist-info/WHEEL'
# adding 'adk_fuzzy_match_bot-0.1.0.dist-info/top_level.txt'
# adding 'adk_fuzzy_match_bot-0.1.0.dist-info/RECORD'
# removing build/bdist.linux-x86_64/wheel
# Successfully built adk_fuzzy_match_bot-0.1.0.tar.gz and adk_fuzzy_match_bot-0.1.0-py3-none-any.whl
# Processing /tmp/packaged_agent/ADK/adk_fuzzy_match_bot/dist/adk_fuzzy_match_bot-0.1.0-py3-none-any.whl
# Requirement already satisfied: google-cloud-aiplatform[adk,agent_engines] in /opt/conda/lib/python3.11/site-packages (from adk-fuzzy-match-bot==0.1.0) (1.87.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1 in /opt/conda/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2.24.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0,>=3.20.2 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (5.29.4)
# Requirement already satisfied: packaging>=14.3 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (24.2)
# Requirement already satisfied: google-cloud-storage<3.0.0,>=1.32.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2.19.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (3.31.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.14.2)
# Requirement already satisfied: shapely<3.0.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2.1.0)
# Requirement already satisfied: pydantic<3 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2.11.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (4.13.1)
# Requirement already satisfied: docstring-parser<1 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (0.16)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (3.1.1)
# Requirement already satisfied: google-cloud-trace<2 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.16.1)
# Requirement already satisfied: google-cloud-logging<4 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (3.12.1)
# Requirement already satisfied: opentelemetry-sdk<2 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.31.1)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.9.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /opt/conda/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.69.2)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /opt/conda/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/conda/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /opt/conda/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.71.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /opt/conda/lib/python3.11/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2.7.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2.8.2)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in /opt/conda/lib/python3.11/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.6.1)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in /opt/conda/lib/python3.11/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (0.3.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /opt/conda/lib/python3.11/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (0.14.2)
# Requirement already satisfied: opentelemetry-api>=1.9.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.31.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-storage<3.0.0,>=1.32.0->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.7.1)
# WARNING: google-cloud-aiplatform 1.87.0 does not provide the extra 'adk'
# Requirement already satisfied: opentelemetry-resourcedetector-gcp==1.*,>=1.5.0dev0 in /opt/conda/lib/python3.11/site-packages (from opentelemetry-exporter-gcp-trace<2->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.9.0a0)
# Requirement already satisfied: deprecated>=1.2.6 in /opt/conda/lib/python3.11/site-packages (from opentelemetry-api>=1.9.0->google-cloud-logging<4->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /opt/conda/lib/python3.11/site-packages (from opentelemetry-api>=1.9.0->google-cloud-logging<4->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (6.8.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.9.0->google-cloud-logging<4->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (3.17.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b1 in /opt/conda/lib/python3.11/site-packages (from opentelemetry-sdk<2->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (0.52b1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /opt/conda/lib/python3.11/site-packages (from pydantic<3->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (0.4.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2023.7.22)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/conda/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (0.6.1)
# Requirement already satisfied: numpy>=1.21 in /opt/conda/lib/python3.11/site-packages (from shapely<3.0.0->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.26.4)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.11/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.9.0->google-cloud-logging<4->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.17.2)
# adk-fuzzy-match-bot is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# UPLOAD FILE TO S3://datalake/Agent/adk_fuzzy_match_bot/adk_fuzzy_match_bot-0.1.0-py3-none-any.whl SUCCESSFULY!
# ☁️ Uploaded adk_fuzzy_match_bot-0.1.0-py3-none-any.whl to s3://datalake/Agent/adk_fuzzy_match_bot/adk_fuzzy_match_bot-0.1.0-py3-none-any.whl
# UPLOAD FILE TO S3://datalake/Agent/adk_fuzzy_match_bot/adk_fuzzy_match_bot-0.1.0.tar.gz SUCCESSFULY!
# ☁️ Uploaded adk_fuzzy_match_bot-0.1.0.tar.gz to s3://datalake/Agent/adk_fuzzy_match_bot/adk_fuzzy_match_bot-0.1.0.tar.gz
# MINIO_KEY : Agent/adk_fuzzy_match_bot/adk_fuzzy_match_bot-0.1.0.tar.gz
# LOCAL_PKG_PATH : /tmp/registered_agent/adk_fuzzy_match_bot-0.1.0.tar.gz
# ⬇️  Downloading Agent/adk_fuzzy_match_bot/adk_fuzzy_match_bot-0.1.0.tar.gz from MinIO...
# ✅ Downloaded to: /tmp/registered_agent/adk_fuzzy_match_bot-0.1.0.tar.gz
# ⛔ Uninstalling any existing versions of adk_fuzzy_match_bot...
# Found existing installation: adk-fuzzy-match-bot 0.1.0
# Uninstalling adk-fuzzy-match-bot-0.1.0:
#   Successfully uninstalled adk-fuzzy-match-bot-0.1.0
# 📦 Installing adk_fuzzy_match_bot-0.1.0.tar.gz...
# Processing /tmp/registered_agent/adk_fuzzy_match_bot-0.1.0.tar.gz
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: google-cloud-aiplatform[adk,agent_engines] in /opt/conda/lib/python3.11/site-packages (from adk-fuzzy-match-bot==0.1.0) (1.87.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1 in /opt/conda/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2.24.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0,>=3.20.2 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (5.29.4)
# Requirement already satisfied: packaging>=14.3 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (24.2)
# Requirement already satisfied: google-cloud-storage<3.0.0,>=1.32.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2.19.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (3.31.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.14.2)
# Requirement already satisfied: shapely<3.0.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2.1.0)
# Requirement already satisfied: pydantic<3 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2.11.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (4.13.1)
# Requirement already satisfied: docstring-parser<1 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (0.16)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (3.1.1)
# Requirement already satisfied: google-cloud-trace<2 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.16.1)
# Requirement already satisfied: google-cloud-logging<4 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (3.12.1)
# Requirement already satisfied: opentelemetry-sdk<2 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.31.1)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2 in /opt/conda/lib/python3.11/site-packages (from google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.9.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /opt/conda/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.69.2)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /opt/conda/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/conda/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /opt/conda/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.71.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /opt/conda/lib/python3.11/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2.7.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2.8.2)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in /opt/conda/lib/python3.11/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.6.1)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in /opt/conda/lib/python3.11/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (0.3.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /opt/conda/lib/python3.11/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (0.14.2)
# Requirement already satisfied: opentelemetry-api>=1.9.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.31.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-storage<3.0.0,>=1.32.0->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.7.1)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp==1.*,>=1.5.0dev0 in /opt/conda/lib/python3.11/site-packages (from opentelemetry-exporter-gcp-trace<2->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.9.0a0)
# Requirement already satisfied: deprecated>=1.2.6 in /opt/conda/lib/python3.11/site-packages (from opentelemetry-api>=1.9.0->google-cloud-logging<4->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /opt/conda/lib/python3.11/site-packages (from opentelemetry-api>=1.9.0->google-cloud-logging<4->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (6.8.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.9.0->google-cloud-logging<4->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (3.17.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b1 in /opt/conda/lib/python3.11/site-packages (from opentelemetry-sdk<2->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (0.52b1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /opt/conda/lib/python3.11/site-packages (from pydantic<3->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (0.4.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (2023.7.22)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/conda/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (0.6.1)
# Requirement already satisfied: numpy>=1.21 in /opt/conda/lib/python3.11/site-packages (from shapely<3.0.0->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.26.4)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.11/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.9.0->google-cloud-logging<4->google-cloud-aiplatform[adk,agent_engines]->adk-fuzzy-match-bot==0.1.0) (1.17.2)
# WARNING: google-cloud-aiplatform 1.87.0 does not provide the extra 'adk'
# Building wheels for collected packages: adk-fuzzy-match-bot
#   Building wheel for adk-fuzzy-match-bot (setup.py): started
#   DEPRECATION: Building 'adk-fuzzy-match-bot' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'adk-fuzzy-match-bot'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for adk-fuzzy-match-bot (setup.py): finished with status 'done'
#   Created wheel for adk-fuzzy-match-bot: filename=adk_fuzzy_match_bot-0.1.0-py3-none-any.whl size=9184 sha256=572aabf8904dbb8d194121c9048d5afa772b9128651545343bead8861a4c2bf9
#   Stored in directory: /home/jovyan/.cache/pip/wheels/80/80/8a/a769033b6d2aad7c22979f335abbc7c0a9e388a84ccba16f5f
# Successfully built adk-fuzzy-match-bot
# Installing collected packages: adk-fuzzy-match-bot
# Successfully installed adk-fuzzy-match-bot-0.1.0
# ✅ Package installed.
# ##############################################################################################

# %% [markdown]
# ### Do the task after this

# %%
import pandas as pd
from io import BytesIO

bucket_name = nb_parm.split('/')[0]
list_path_to_file = nb_parm.split('/')[1:]
path_to_file = "/".join(list_path_to_file)

byte_csv_data = base_tools.read_file_from_datalake(bucket_name, path_to_file)
data = BytesIO(byte_csv_data)
df = pd.read_csv(data)

df
# Out:
#                    Feed Name
# 0         AR_ACCOUNT_BALANCE
# 1         AR_AUTOPAY_LOG_DTN
# 2     AR_AUTOPAY_REQUEST_DTN
# 3        AR_AUTOPAY_RESPONSE
# 4    AR_AUTOPAY_RESPONSE_DTN
# ..                       ...
# 221           CDR_RETURN_DTN
# 222              CDR_SMS_DTN
# 223         CDR_SYLOWBAL_DTN
# 224              CDR_VOU_DTN
# 225   SOF_EXPIRED_SUBSCR_DTN
#
# [226 rows x 1 columns]

# %%
# === Use your agent ===
import uuid
import ast
from dotenv import load_dotenv
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService
from google.genai import types
from adk_fuzzy_match_bot.agent import root_agent as fuzzy_match_bot
import warnings
warnings.filterwarnings("ignore", category=ResourceWarning)

load_dotenv("/home/jovyan/notebooks/.env")


# Create a new session service to store state
session_service_stateful = InMemorySessionService()

# Create a NEW session
APP_NAME = "CBS_matching"
USER_ID = "cbs_user"
SESSION_ID = str(uuid.uuid4())
stateful_session = session_service_stateful.create_session(
    app_name=APP_NAME,
    user_id=USER_ID,
    session_id=SESSION_ID,
)
print("CREATED NEW SESSION:")
print(f"\tSession ID: {SESSION_ID}")

runner = Runner(
    agent=fuzzy_match_bot,
    app_name=APP_NAME,
    session_service=session_service_stateful,
)

column = ['feed_word','matching_word','score','reasoning']
new_df = []

i = 1
for feed_word in df.iloc[:,0]:
    
    new_message = types.Content(
        role="user", parts=[types.Part(text=str(feed_word))]
    )
    
    for event in runner.run(
        user_id=USER_ID,
        session_id=SESSION_ID,
        new_message=new_message,
    ):
        if event.is_final_response():
            if event.content and event.content.parts:
                list_ot_output = [_.strip().replace('\n','').replace('```text', '').replace('```','').replace("\\","") for _ in event.content.parts[0].text.split('|')]
                for _ in list_ot_output:
                    if len(i) != 0:
                        new_df.append(ast.literal_eval(_.replace('json', '')))
    print(f"Finish process: {i}: [{feed_word}]: {list_ot_output}")
    i += 1

final_df = pd.DataFrame(new_df, columns=column)
print("### Finish Call AI Agent")
# Out:
# CREATED NEW SESSION:
# 	Session ID: 77755ac0-fc03-443e-adc7-e251baad0911
# Warning: there are non-text parts in the response: ['function_call'],returning concatenated text result from text parts,check out the non text parts for full response from model.
# Finish process: 1: [AR_ACCOUNT_BALANCE]: ['json["AR_ACCOUNT_BALANCE", "AR_ACCOUNT_BALANCE", 1.0, "Exact match"]']
# Finish process: 2: [AR_AUTOPAY_LOG_DTN]: ['["AR_AUTOPAY_LOG_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 3: [AR_AUTOPAY_REQUEST_DTN]: ['["AR_AUTOPAY_REQUEST_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 4: [AR_AUTOPAY_RESPONSE]: ['["AR_AUTOPAY_RESPONSE", "No Match", 0, "No reason"]', '']
# Finish process: 5: [AR_AUTOPAY_RESPONSE_DTN]: ['["AR_AUTOPAY_RESPONSE_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 6: [AR_BATCH_PAYMENT]: ['["AR_BATCH_PAYMENT", "AR_PAYMENT", 0.73, "Partial match on \'AR\' and \'PAYMENT\'"]', '["AR_BATCH_PAYMENT", "AR_PAYMENT_BO", 0.64, "Partial match on \'AR\' and \'PAYMENT\'"]', '']
# Finish process: 7: [AR_BATCH_PAYMENT_DTN]: ['["AR_BATCH_PAYMENT_DTN", "AR_PAYMENT", 0.6, "Partial match on \'AR\' and \'PAYMENT\'"]', '["AR_BATCH_PAYMENT_DTN", "AR_PAYMENT_BO", 0.53, "Partial match on \'AR\' and \'PAYMENT\'"]', '']
# Finish process: 8: [AR_CBS_AUTOPAY_REGISTER_LOG]: ['["AR_CBS_AUTOPAY_REGISTER_LOG", "No Match", 0, "No reason"]', '']
# Finish process: 9: [AR_CBS_AUTOPAY_REGISTER_LOG_DTN]: ['["AR_CBS_AUTOPAY_REGISTER_LOG_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 10: [AR_CFG_PARAM_COMP_CODE]: ['["AR_CFG_PARAM_COMP_CODE", "No Match", 0, "No reason"]', '']
# Finish process: 11: [AR_CFG_PARAM_COMP_CODE_DTN]: ['["AR_CFG_PARAM_COMP_CODE_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 12: [AR_CFG_PARAM_DOCUMENT_CODE]: ['["AR_CFG_PARAM_DOCUMENT_CODE", "No Match", 0, "No reason"]', '']
# Finish process: 13: [AR_CFG_PARAM_DOCUMENT_CODE_DTN]: ['["AR_CFG_PARAM_DOCUMENT_CODE_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 14: [AR_CREDIT_BALANCE]: ['json["AR_CREDIT_BALANCE", "AR_CREDIT_BALANCE", 1.0, "Exact match"]']
# Finish process: 15: [AR_CREDIT_BALANCE_DTN]: ['["AR_CREDIT_BALANCE_DTN", "AR_CREDIT_BALANCE", 0.83, "Partial match on \'AR_CREDIT_BALANCE\'"]', '']
# Finish process: 16: [AR_CREDIT_LOG]: ['["AR_CREDIT_LOG", "AR_CREDIT_BALANCE", 0.67, "Partial match on \'AR_CREDIT\'"]', '']
# Finish process: 17: [AR_CREDIT_LOG_DTN]: ['["AR_CREDIT_LOG_DTN", "AR_CREDIT_BALANCE", 0.6, "Partial match on \'AR_CREDIT\'"]', '']
# Finish process: 18: [AR_CUST_ABB2COMP]: ['["AR_CUST_ABB2COMP", "No Match", 0, "No reason"]', '']
# Finish process: 19: [AR_CUST_ABB2COMP_DOB_DTN]: ['["AR_CUST_ABB2COMP_DOB_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 20: [AR_CUST_ABB2COMP_DTN]: ['["AR_CUST_ABB2COMP_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 21: [AR_CUST_CHEQUE_PAYMENT]: ['["AR_CUST_CHEQUE_PAYMENT", "AR_PAYMENT", 0.62, "Partial match on \'AR\' and \'PAYMENT\'"]', '["AR_CUST_CHEQUE_PAYMENT", "AR_PAYMENT_BO", 0.55, "Partial match on \'AR\' and \'PAYMENT\'"]', '']
# Finish process: 22: [AR_CUST_CHEQUE_PMT_DTN]: ['["AR_CUST_CHEQUE_PMT_DTN", "AR_PAYMENT", 0.52, "Partial match on \'AR\' and \'PMT\'"]', '["AR_CUST_CHEQUE_PMT_DTN", "AR_PAYMENT_BO", 0.46, "Partial match on \'AR\' and \'PMT\'"]', '']
# Finish process: 23: [AR_CUST_EVC_PRT_SRC_DTN]: ['["AR_CUST_EVC_PRT_SRC_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 24: [AR_CUST_EXT_PRT_SRC_DOB_DTN]: ['["AR_CUST_EXT_PRT_SRC_DOB_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 25: [AR_CUST_EXT_PRT_SRC_DTN]: ['["AR_CUST_EXT_PRT_SRC_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 26: [AR_CUST_PRINT_SRC]: ['["AR_CUST_PRINT_SRC", "No Match", 0, "No reason"]', '']
# Finish process: 27: [AR_CUST_PRINT_SRC_DTN]: ['["AR_CUST_PRINT_SRC_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 28: [AR_DIC_BANK_INFO]: ['["AR_DIC_BANK_INFO", "No Match", 0, "No reason"]', '']
# Finish process: 29: [AR_DIC_BANK_INFO_DTN]: ['["AR_DIC_BANK_INFO_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 30: [AR_DIC_CHANNEL]: ['json["AR_DIC_CHANNEL", "AR_DIC_CHANNEL", 1.0, "Exact match"]']
# Finish process: 31: [AR_DIC_CHANNEL_DTN]: ['json["AR_DIC_CHANNEL_DTN", "AR_DIC_CHANNEL", 0.86, "Partial match on \'AR_DIC_CHANNEL\'"]']
# Finish process: 32: [AR_DIC_PAYMENT_METHOD]: ['json["AR_DIC_PAYMENT_METHOD", "AR_DIC_PAYMENT_METHOD", 1.0, "Exact match"]']
# Finish process: 33: [AR_DIC_PAYMENT_METHOD_DTN]: ['json["AR_DIC_PAYMENT_METHOD_DTN", "AR_DIC_PAYMENT_METHOD", 0.89, "Partial match on \'AR_DIC_PAYMENT_METHOD\'"]']
# Finish process: 34: [AR_DIC_REASON_CODE]: ['json["AR_DIC_REASON_CODE", "AR_DIC_REASON_CODE", 1.0, "Exact match"]']
# Finish process: 35: [AR_DIC_REASON_CODE_DTN]: ['json["AR_DIC_REASON_CODE_DTN", "AR_DIC_REASON_CODE", 0.88, "Partial match on \'AR_DIC_REASON_CODE\'"]']
# Finish process: 36: [AR_DIC_TRX_TYPE]: ['json["AR_DIC_TRX_TYPE", "AR_DIC_TRX_TYPE", 1.0, "Exact match"]']
# Finish process: 37: [AR_DIC_TRX_TYPE_DTN]: ['json["AR_DIC_TRX_TYPE_DTN", "AR_DIC_TRX_TYPE", 0.83, "Partial match on \'AR_DIC_TRX_TYPE\'"]']
# Finish process: 38: [AR_INVOICE]: ['json["AR_INVOICE", "AR_INVOICE", 1.0, "Exact match"]']
# Finish process: 39: [AR_INVOICE_DETAIL]: ['json["AR_INVOICE_DETAIL", "AR_INVOICE_DETAIL", 1.0, "Exact match"]']
# Finish process: 40: [AR_INVOICE_DETAIL_DTN]: ['json["AR_INVOICE_DETAIL_DTN", "AR_INVOICE_DETAIL", 0.86, "Partial match on \'AR_INVOICE_DETAIL\'"]']
# Finish process: 41: [AR_INVOICE_DTN]: ['json["AR_INVOICE_DTN", "AR_INVOICE", 0.86, "Partial match on \'AR_INVOICE\'"]']
# Finish process: 42: [AR_LOG_BILL2AR_STAT]: ['["AR_LOG_BILL2AR_STAT", "No Match", 0, "No reason"]', '']
# Finish process: 43: [AR_LOG_BILL2AR_STAT_DTN]: ['["AR_LOG_BILL2AR_STAT_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 44: [AR_LOG_REQUEST]: ['["AR_LOG_REQUEST", "AR_REQUEST_DETAIL", 0.6, "Partial match on \'AR\' and \'REQUEST\'"]', '']
# Finish process: 45: [AR_LOG_REQUEST_DOB_DTN]: ['["AR_LOG_REQUEST_DOB_DTN", "AR_REQUEST_DETAIL", 0.46, "Partial match on \'AR\' and \'REQUEST\'"]', '']
# Finish process: 46: [AR_LOG_REQUEST_DTN]: ['["AR_LOG_REQUEST_DTN", "AR_REQUEST_DETAIL", 0.53, "Partial match on \'AR\' and \'REQUEST\'"]', '']
# Finish process: 47: [AR_LOG_TRX]: ['json["AR_LOG_TRX", "AR_LOG_TRX", 1.0, "Exact match"]']
# Finish process: 48: [AR_LOG_TRX_DETAIL]: ['json["AR_LOG_TRX_DETAIL", "AR_LOG_TRX_DETAIL", 1.0, "Exact match"]']
# Finish process: 49: [AR_LOG_TRX_DETAIL_DTN]: ['json["AR_LOG_TRX_DETAIL_DTN", "AR_LOG_TRX_DETAIL", 0.86, "Partial match on \'AR_LOG_TRX_DETAIL\'"]']
# Finish process: 50: [AR_LOG_TRX_DTN]: ['json["AR_LOG_TRX_DTN", "AR_LOG_TRX", 0.86, "Partial match on \'AR_LOG_TRX\'"]']
# Finish process: 51: [AR_PAYMENT]: ['json["AR_PAYMENT", "AR_PAYMENT", 1.0, "Exact match"]']
# Finish process: 52: [AR_PAYMENT_DTN]: ['json["AR_PAYMENT_DTN", "AR_PAYMENT", 0.86, "Partial match on \'AR_PAYMENT\'"]']
# Finish process: 53: [AR_REFUND]: ['json["AR_REFUND", "AR_REFUND", 1.0, "Exact match"]']
# Finish process: 54: [AR_REFUND_DTN]: ['json["AR_REFUND_DTN", "AR_REFUND", 0.86, "Partial match on \'AR_REFUND\'"]']
# Finish process: 55: [AR_TS_I18N_RESOURCE]: ['["AR_TS_I18N_RESOURCE", "No Match", 0, "No reason"]', '']
# Finish process: 56: [AR_TS_I18N_RESOURCE_DTN]: ['["AR_TS_I18N_RESOURCE_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 57: [AR_WRITEOFF_LOG]: ['["AR_WRITEOFF_LOG", "AR_WRITEOFF", 0.73, "Partial match on \'AR_WRITEOFF\'"]', '']
# Exception in thread Thread-119 (_asyncio_thread_main):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/httpx/_transports/default.py", line 101, in map_httpcore_exceptions
#     yield
#   File "/opt/conda/lib/python3.11/site-packages/httpx/_transports/default.py", line 394, in handle_async_request
#     resp = await self._pool.handle_async_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/httpcore/_async/connection_pool.py", line 256, in handle_async_request
#     raise exc from None
#   File "/opt/conda/lib/python3.11/site-packages/httpcore/_async/connection_pool.py", line 236, in handle_async_request
#     response = await connection.handle_async_request(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/httpcore/_async/connection.py", line 101, in handle_async_request
#     raise exc
#   File "/opt/conda/lib/python3.11/site-packages/httpcore/_async/connection.py", line 78, in handle_async_request
#     stream = await self._connect(request)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/httpcore/_async/connection.py", line 156, in _connect
#     stream = await stream.start_tls(**kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/httpcore/_backends/anyio.py", line 67, in start_tls
#     with map_exceptions(exc_map):
#   File "/opt/conda/lib/python3.11/contextlib.py", line 155, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "/opt/conda/lib/python3.11/site-packages/httpcore/_exceptions.py", line 14, in map_exceptions
#     raise to_exc(exc) from exc
# httpcore.ConnectError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/conda/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.11/site-packages/google/adk/runners.py", line 138, in _asyncio_thread_main
#     asyncio.run(_invoke_run_async())
#   File "/opt/conda/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/asyncio/base_events.py", line 653, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/google/adk/runners.py", line 126, in _invoke_run_async
#     async for event in self.run_async(
#   File "/opt/conda/lib/python3.11/site-packages/google/adk/runners.py", line 197, in run_async
#     async for event in invocation_context.agent.run_async(invocation_context):
#   File "/opt/conda/lib/python3.11/site-packages/google/adk/agents/base_agent.py", line 141, in run_async
#     async for event in self._run_async_impl(ctx):
#   File "/opt/conda/lib/python3.11/site-packages/google/adk/agents/llm_agent.py", line 232, in _run_async_impl
#     async for event in self._llm_flow.run_async(ctx):
#   File "/opt/conda/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 231, in run_async
#     async for event in self._run_one_step_async(invocation_context):
#   File "/opt/conda/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 257, in _run_one_step_async
#     async for llm_response in self._call_llm_async(
#   File "/opt/conda/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 470, in _call_llm_async
#     async for llm_response in llm.generate_content_async(
#   File "/opt/conda/lib/python3.11/site-packages/google/adk/models/google_llm.py", line 140, in generate_content_async
#     response = await self.api_client.aio.models.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/google/genai/models.py", line 6269, in generate_content
#     response = await self._generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/google/genai/models.py", line 5271, in _generate_content
#     response_dict = await self._api_client.async_request(
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/google/genai/_api_client.py", line 760, in async_request
#     result = await self._async_request(http_request=http_request, stream=False)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/google/genai/_api_client.py", line 697, in _async_request
#     response = await self._async_httpx_client.request(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/httpx/_client.py", line 1540, in request
#     return await self.send(request, auth=auth, follow_redirects=follow_redirects)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/httpx/_client.py", line 1629, in send
#     response = await self._send_handling_auth(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/httpx/_client.py", line 1657, in _send_handling_auth
#     response = await self._send_handling_redirects(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/httpx/_client.py", line 1694, in _send_handling_redirects
#     response = await self._send_single_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/httpx/_client.py", line 1730, in _send_single_request
#     response = await transport.handle_async_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/httpx/_transports/default.py", line 393, in handle_async_request
#     with map_httpcore_exceptions():
#   File "/opt/conda/lib/python3.11/contextlib.py", line 155, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "/opt/conda/lib/python3.11/site-packages/httpx/_transports/default.py", line 118, in map_httpcore_exceptions
#     raise mapped_exc(message) from exc
# httpx.ConnectError
# Finish process: 58: [AR_WRITEOFF_LOG_DTN]: ['["AR_WRITEOFF_LOG", "AR_WRITEOFF", 0.73, "Partial match on \'AR_WRITEOFF\'"]', '']
# Finish process: 59: [BLL_BILLCYCLEID_DTN]: ['["AR_WRITEOFF_LOG_DTNBLL_BILLCYCLEID_DTN", "AR_WRITEOFF", 0.34, "Partial match on \'AR_WRITEOFF\'"]', '']
# Finish process: 60: [BLL_BILLCYCLETYPE_DTN]: ['["BLL_BILLCYCLETYPE_DTN", "BB_DIC_BILL_CYCLE_TYPE", 0.4, "Partial match on \'BILL_CYCLE_TYPE\'"]', '']
# Finish process: 61: [BLL_CBS_USAGERPTLOG_DTN]: ['["BLL_CBS_USAGERPTLOG_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 62: [BLL_CDR_ACCT_SYSMSG_DTN]: ['["BLL_CDR_ACCT_SYSMSG_DTN", "BC_ACCT", 0.31, "Partial match on \'ACCT\'"]', '']
# Finish process: 63: [BLL_CHARGE_DTN]: ['["BLL_CHARGE_DTN", "BILL_CHARGE_BO", 0.5, "Partial match on \'CHARGE\'"]', '["BLL_CHARGE_DTN", "CM_CHARGE_CODE", 0.5, "Partial match on \'CHARGE\'"]', '']
# Finish process: 64: [BLL_DATA_DTN]: ['["BLL_DATA_DTN", "SD_AREA", 0.24, "Partial match on \'DATA\'"]', '']
# Finish process: 65: [BLL_DIC_BILL_TEMPLATE_DTN]: ['["BLL_DIC_BILL_TEMPLATE_DTN", "BB_DIC_BILL_CYCLE", 0.5, "Partial match on \'DIC_BILL\'"]', '["BLL_DIC_BILL_TEMPLATE_DTN", "BB_DIC_BILL_CYCLE_TYPE", 0.5, "Partial match on \'DIC_BILL\'"]', '["BLL_DIC_BILL_TEMPLATE_DTN", "BB_DIC_BILL_MEDIUM", 0.43, "Partial match on \'DIC_BILL\'"]', '']
# Finish process: 66: [BLL_DIC_SERVICE_GROUP_DTN]: ['["BLL_DIC_SERVICE_GROUP_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 67: [BLL_LOG_IVR_INVOICE_DTN]: ['["BLL_LOG_IVR_INVOICE_DTN", "AR_INVOICE", 0.46, "Partial match on \'INVOICE\'"]', '["BLL_LOG_IVR_INVOICE_DTN", "AR_INVOICE_BO", 0.43, "Partial match on \'INVOICE\'"]', '["BLL_LOG_IVR_INVOICE_DTN", "AR_INVOICE_DETAIL", 0.53, "Partial match on \'INVOICE\'"]', '["BLL_LOG_IVR_INVOICE_DTN", "BILL_INVOICE_BO", 0.53, "Partial match on \'INVOICE\'"]', '']
# Finish process: 68: [BLL_OCS_ACCOUNT_EXT_DTN]: ['["BLL_OCS_ACCOUNT_EXT_DTN", "BC_ACCT", 0.35, "Partial match on \'ACCT\'"]', '']
# Finish process: 69: [BLL_OCS_BA_DELIVERY_DTN]: ['["BLL_OCS_BA_DELIVERY_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 70: [BLL_OCS_BA_DTN]: ['["BLL_OCS_BA_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 71: [BLL_OCS_SUBSCRIBER_EXT_DTN]: ['["BLL_OCS_SUBSCRIBER_EXT_DTN", "BC_SUBSCRIBER", 0.57, "Partial match on \'SUBSCRIBER\'"]', '']
# Finish process: 72: [BLL_OCS_USAGESERVICE_DTN]: ['["BLL_OCS_USAGESERVICE_DTN", "EF_GPRS_SERVICE", 0.5, "Partial match on \'SERVICE\'"]', '']
# Finish process: 73: [BLL_SUM_POS_DTN]: ['["BLL_SUM_POS_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 74: [BLL_T_BME_OPERATOR_DTN]: ['["BLL_T_BME_OPERATOR_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 75: [BLL_T_BME_ORGANIZATION]: ['["BLL_T_BME_ORGANIZATION", "BC_ORG", 0.42, "Partial match on \'ORG\'"]', '["BLL_T_BME_ORGANIZATION", "SYS_ORG", 0.42, "Partial match on \'ORG\'"]', '']
# Finish process: 76: [BLL_T_BME_ORGANIZATION_DTN]: ['["BLL_T_BME_ORGANIZATION_DTN", "BC_ORG", 0.39, "Partial match on \'ORG\'"]', '["BLL_T_BME_ORGANIZATION_DTN", "SYS_ORG", 0.39, "Partial match on \'ORG\'"]', '']
# Finish process: 77: [BLL_TB_TAXPKG_DTN]: ['["BLL_TB_TAXPKG_DTN", "AR_TAX_DETAIL", 0.33, "Partial match on \'TAX\'"]', '']
# Finish process: 78: [BLL_TB_TAXRATE_DTN]: ['["BLL_TB_TAXRATE_DTN", "AR_TAX_DETAIL", 0.36, "Partial match on \'TAX\'"]', '']
# Finish process: 79: [BLL_TS_AUTHFIELD]: ['["BLL_TS_AUTHFIELD", "No Match", 0, "No reason"]', '']
# Finish process: 80: [BLL_TS_AUTHFIELD_DTN]: ['["BLL_TS_AUTHFIELD_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 81: [BLL_TS_GROUPCUSTOMER_DTN]: ['["BLL_TS_GROUPCUSTOMER_DTN", "BB_DIC_CUSTGRP", 0.5, "Partial match on \'CUST\'"]', '["BLL_TS_GROUPCUSTOMER_DTN", "BC_CUSTOMER", 0.46, "Partial match on \'CUST\'"]', '']
# Finish process: 82: [BLL_TS_PAYMENTRELATION_DTN]: ['["BLL_TS_PAYMENTRELATION_DTN", "BC_PAYMENT_RELATION", 0.73, "Partial match on \'PAYMENT_RELATION\'"]', '["BLL_TS_PAYMENTRELATION_DTN", "BC_PAYMENT_CHANNEL", 0.67, "Partial match on \'PAYMENT\'"]', '["BLL_TS_PAYMENTRELATION_DTN", "AR_PAYMENT", 0.4, "Partial match on \'PAYMENT\'"]', '["BLL_TS_PAYMENTRELATION_DTN", "AR_PAYMENT_BO", 0.36, "Partial match on \'PAYMENT\'"]', '']
# Finish process: 83: [CBS_ACCOUNT_DTN]: ['["CBS_ACCOUNT_DTN", "BC_ACCT", 0.53, "Partial match on \'ACCT\'"]', '']
# Finish process: 84: [CBS_ACCOUNT_TYPE_DTN]: ['["CBS_ACCOUNT_TYPE_DTN", "BC_ACCT", 0.48, "Partial match on \'ACCT\'"]', '']
# Finish process: 85: [CBS_ADJUSTMENT_REASONCODE_DTN]: ['["CBS_ADJUSTMENT_REASONCODE_DTN", "AR_DIC_REASON_CODE", 0.5, "Partial match on \'REASON_CODE\'"]', '["CBS_ADJUSTMENT_REASONCODE_DTN", "RB_ADJUSTMENT", 0.44, "Partial match on \'ADJUSTMENT\'"]', '["CBS_ADJUSTMENT_REASONCODE_DTN", "AR_ADJUSTMENT", 0.44, "Partial match on \'ADJUSTMENT\'"]', '']
# Finish process: 86: [CBS_AMPHOE_DTN]: ['["CBS_AMPHOE_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 87: [CBS_AOU_DTN]: ['["CBS_AOU_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 88: [CBS_BILLINGCYCLETPE_DTN]: ['["CBS_BILLINGCYCLETPE_DTN", "BB_DIC_BILL_CYCLE_TYPE", 0.67, "Partial match on \'BILLING_CYCLE\'"]', '["CBS_BILLINGCYCLETPE_DTN", "BB_DIC_BILL_CYCLE", 0.61, "Partial match on \'BILLING_CYCLE\'"]', '']
# Finish process: 89: [CBS_BLACKLIST_AR_DTN]: ['["CBS_BLACKLIST_AR_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 90: [CBS_BMP_CBE_SUBSCR_DTN]: ['["CBS_BMP_CBE_SUBSCR_DTN", "BC_SUBSCRIBER", 0.57, "Partial match on \'SUBSCRIBER\'"]', '']
# Finish process: 91: [CBS_CBE_ACCOUNT_DYN_DTN]: ['["CBS_CBE_ACCOUNT_DYN_DTN", "BC_ACCT", 0.59, "Partial match on \'ACCT\'"]', '']
# Finish process: 92: [CBS_CBE_CUMULATEID_DTN]: ['["CBS_CBE_CUMULATEID_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 93: [CBS_CBE_POLICY_DTN]: ['["CBS_CBE_POLICY_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 94: [CBS_CC_ACTION_DTN]: ['["CBS_CC_ACTION_DTN", "DC_ACTION", 0.53, "Partial match on \'ACTION\'"]', '']
# Finish process: 95: [CBS_CC_DETAIL_DTN]: ['["CBS_CC_DETAIL_DTN", "AR_INVOICE_DETAIL", 0.36, "Partial match on \'DETAIL\'"]', '["CBS_CC_DETAIL_DTN", "AR_APPLY_DETAIL", 0.4, "Partial match on \'DETAIL\'"]', '["CBS_CC_DETAIL_DTN", "AR_LOG_TRX_DETAIL", 0.36, "Partial match on \'DETAIL\'"]', '["CBS_CC_DETAIL_DTN", "AR_REQUEST_DETAIL", 0.4, "Partial match on \'DETAIL\'"]', '["CBS_CC_DETAIL_DTN", "AR_TAX_DETAIL", 0.33, "Partial match on \'DETAIL\'"]', '["CBS_CC_DETAIL_DTN", "CM_SS_DETAIL_DEFINITON", 0.32, "Partial match on \'DETAIL\'"]', '["CBS_CC_DETAIL_DTN", "DC_PA_DETAIL", 0.44, "Partial match on \'DETAIL\'"]', '']
# Finish process: 96: [CBS_CDR_OFM]: ['["CBS_CDR_OFM", "No Match", 0, "No reason"]', '']
# Finish process: 97: [CBS_CDR_SPLUNK]: ['["CBS_CDR_SPLUNK", "No Match", 0, "No reason"]', '']
# Finish process: 98: [CBS_CELLID_DTN]: ['["CBS_CELLID_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 99: [CBS_CODE_DICT_DTN]: ['["CBS_CODE_DICT_DTN", "AR_DIC_CHANNEL", 0.31, "Partial match on \'DICT\'"]', '["CBS_CODE_DICT_DTN", "AR_DIC_CREDIT_CARD_TYPE", 0.31, "Partial match on \'DICT\'"]', '["CBS_CODE_DICT_DTN", "AR_DIC_PAYMENT_METHOD", 0.31, "Partial match on \'DICT\'"]', '["CBS_CODE_DICT_DTN", "AR_DIC_REASON_CODE", 0.31, "Partial match on \'DICT\'"]', '["CBS_CODE_DICT_DTN", "AR_DIC_REFUND_TYPE", 0.31, "Partial match on \'DICT\'"]', '["CBS_CODE_DICT_DTN", "AR_DIC_TRX_TYPE", 0.31, "Partial match on \'DICT\'"]', '["CBS_CODE_DICT_DTN", "BB_DIC_BILL_CYCLE", 0.31, "Partial match on \'DICT\'"]', '["CBS_CODE_DICT_DTN", "BB_DIC_BILL_CYCLE_TYPE", 0.31, "Partial match on \'DICT\'"]', '["CBS_CODE_DICT_DTN", "BB_DIC_BILL_MEDIUM", 0.31, "Partial match on \'DICT\'"]', '["CBS_CODE_DICT_DTN", "BB_DIC_CUSTGRP", 0.31, "Partial match on \'DICT\'"]', '["CBS_CODE_DICT_DTN", "SYS_DIC_CURRENCY", 0.31, "Partial match on \'DICT\'"]', '["CBS_CODE_DICT_DTN", "SYS_DIC_TIMEZONE", 0.31, "Partial match on \'DICT\'"]', '']
# Finish process: 100: [CBS_CORPCUSTOMER_DTN]: ['["CBS_CORPCUSTOMER_DTN", "BC_CUSTOMER", 0.53, "Partial match on \'CUSTOMER\'"]', '']
# Finish process: 101: [CBS_CREDIT_LIMIT_DTN]: ['["CBS_CREDIT_LIMIT_DTN", "CM_CREDIT_LIMIT", 0.86, "Partial match on \'CREDIT_LIMIT\'"]', '["CBS_CREDIT_LIMIT_DTN", "CM_CREDIT_LIMIT_ACCM", 0.73, "Partial match on \'CREDIT_LIMIT\'"]', '["CBS_CREDIT_LIMIT_DTN", "CM_CREDIT_LIMIT_VALUE", 0.67, "Partial match on \'CREDIT_LIMIT\'"]', '["CBS_CREDIT_LIMIT_DTN", "PE_CREDIT_LIMIT_TYPE", 0.64, "Partial match on \'CREDIT_LIMIT\'"]', '']
# Finish process: 102: [CBS_CREDIT_SEGMENT]: ['["CBS_CREDIT_SEGMENT", "CM_CREDIT_LIMIT", 0.67, "Partial match on \'CREDIT\'"]', '["CBS_CREDIT_SEGMENT", "CM_CREDIT_LIMIT_ACCM", 0.57, "Partial match on \'CREDIT\'"]', '["CBS_CREDIT_SEGMENT", "CM_CREDIT_LIMIT_VALUE", 0.53, "Partial match on \'CREDIT\'"]', '["CBS_CREDIT_SEGMENT", "PE_CREDIT_LIMIT_TYPE", 0.5, "Partial match on \'CREDIT\'"]', '["CBS_CREDIT_SEGMENT", "AR_CREDIT_BALANCE", 0.5, "Partial match on \'CREDIT\'"]', '']
# Finish process: 103: [CBS_CUSTOMER_DTN]: ['["CBS_CUSTOMER_DTN", "BC_CUSTOMER", 0.8, "Partial match on \'CUSTOMER\'"]', '']
# Finish process: 104: [CBS_DC_ACCT_COURTCASE_INFO]: ['["CBS_DC_ACCT_COURTCASE_INFO", "BC_ACCT", 0.42, "Partial match on \'ACCT\'"]', '']
# Finish process: 105: [CBS_DC_ACCT_COURTCASE_INFO_DTN]: ['["CBS_DC_ACCT_COURTCASE_INFO_DTN", "BC_ACCT", 0.39, "Partial match on \'ACCT\'"]', '']
# Finish process: 106: [CBS_DC_ACCT_GRP_RELATION]: ['["CBS_DC_ACCT_GRP_RELATION", "BC_ACCT", 0.44, "Partial match on \'ACCT\'"]', '']
# Finish process: 107: [CBS_DC_ACCT_GRP_RELATION_DTN]: ['["CBS_DC_ACCT_GRP_RELATION_DTN", "BC_ACCT", 0.42, "Partial match on \'ACCT\'"]', '']
# Finish process: 108: [CBS_DC_ACTION]: ['["CBS_DC_ACTION", "DC_ACTION", 0.8, "Partial match on \'ACTION\'"]', '']
# Finish process: 109: [CBS_DC_ACTION_DTN]: ['["CBS_DC_ACTION_DTN", "DC_ACTION", 0.76, "Partial match on \'ACTION\'"]', '']
# Finish process: 110: [CBS_DC_AGENCY_ORDER]: ['["CBS_DC_AGENCY_ORDER", "DC_TASK_ORDER_4Q", 0.53, "Partial match on \'ORDER\'"]', '']
# Finish process: 111: [CBS_DC_AGENCY_ORDER_DTN]: ['["CBS_DC_AGENCY_ORDER_DTN", "DC_TASK_ORDER_4Q", 0.5, "Partial match on \'ORDER\'"]', '']
# Finish process: 112: [CBS_DC_COLLECT_GROUP]: ['["CBS_DC_COLLECT_GROUP", "No Match", 0, "No reason"]', '']
# Finish process: 113: [CBS_DC_COLLECT_GROUP_DTN]: ['["CBS_DC_COLLECT_GROUP_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 114: [CBS_DC_COLLECT_HOLD]: ['["CBS_DC_COLLECT_HOLD", "DC_HOLD_INSTANCE", 0.57, "Partial match on \'HOLD\'"]', '']
# Finish process: 115: [CBS_DC_COLLECT_HOLD_DTN]: ['["CBS_DC_COLLECT_HOLD_DTN", "DC_HOLD_INSTANCE", 0.53, "Partial match on \'HOLD\'"]', '']
# Finish process: 116: [CBS_DC_COLLECT_HOLD_REASON]: ['["CBS_DC_COLLECT_HOLD_REASON", "DC_HOLD_INSTANCE", 0.46, "Partial match on \'HOLD\'"]', '']
# Finish process: 117: [CBS_DC_COLLECT_HOLD_REASON_DTN]: ['["CBS_DC_COLLECT_HOLD_REASON_DTN", "DC_HOLD_INSTANCE", 0.43, "Partial match on \'HOLD\'"]', '']
# Finish process: 118: [CBS_DC_HOLD_INSTANCE]: ['["CBS_DC_HOLD_INSTANCE", "DC_HOLD_INSTANCE", 0.88, "Partial match on \'HOLD_INSTANCE\'"]', '']
# Finish process: 119: [CBS_DC_HOLD_INSTANCE_DTN]: ['["CBS_DC_HOLD_INSTANCE_DTN", "DC_HOLD_INSTANCE", 0.85, "Partial match on \'HOLD_INSTANCE\'"]', '']
# Finish process: 120: [CBS_DC_OUTSOURCE_AGENCY_CHG_HIS]: ['["CBS_DC_OUTSOURCE_AGENCY_CHG_HIS", "No Match", 0, "No reason"]', '']
# Finish process: 121: [CBS_DC_OUTSOURCE_AGENCY_CHG_HIS_DTN]: ['["CBS_DC_OUTSOURCE_AGENCY_CHG_HIS_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 122: [CBS_DC_OUTSOURCE_COLLECT_AGENCY]: ['["CBS_DC_OUTSOURCE_COLLECT_AGENCY", "No Match", 0, "No reason"]', '']
# Finish process: 123: [CBS_DC_OUTSOURCE_COLLECT_AGENCY_DTN]: ['["CBS_DC_OUTSOURCE_COLLECT_AGENCY_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 124: [CBS_DC_PA_DETAIL]: ['["CBS_DC_PA_DETAIL", "DC_PA_DETAIL", 0.8, "Partial match on \'PA_DETAIL\'"]', '']
# Finish process: 125: [CBS_DC_PA_DETAIL_DTN]: ['["CBS_DC_PA_DETAIL_DTN", "DC_PA_DETAIL", 0.76, "Partial match on \'PA_DETAIL\'"]', '']
# Finish process: 126: [CBS_DC_PA_PLAN]: ['["CBS_DC_PA_PLAN", "DC_PA_PLAN", 0.8, "Partial match on \'PA_PLAN\'"]', '']
# Finish process: 127: [CBS_DC_PA_PLAN_DTN]: ['["CBS_DC_PA_PLAN_DTN", "DC_PA_PLAN", 0.76, "Partial match on \'PA_PLAN\'"]', '']
# Finish process: 128: [CBS_DC_TASK_ORDER]: ['["CBS_DC_TASK_ORDER", "DC_TASK_ORDER_4Q", 0.8, "Partial match on \'TASK_ORDER\'"]', '']
# Finish process: 129: [CBS_DC_TASK_ORDER_ATTR]: ['["CBS_DC_TASK_ORDER_ATTR", "DC_TASK_ORDER_4Q", 0.62, "Partial match on \'TASK_ORDER\'"]', '']
# Finish process: 130: [CBS_DC_TASK_ORDER_ATTR_DTN]: ['["CBS_DC_TASK_ORDER_ATTR_DTN", "DC_TASK_ORDER_4Q", 0.59, "Partial match on \'TASK_ORDER\'"]', '']
# Finish process: 131: [CBS_DC_TASK_ORDER_CHANGE_LOG]: ['["CBS_DC_TASK_ORDER_CHANGE_LOG", "DC_TASK_ORDER_4Q", 0.5, "Partial match on \'TASK_ORDER\'"]', '']
# Finish process: 132: [CBS_DC_TASK_ORDER_CHANGE_LOG_DTN]: ['["CBS_DC_TASK_ORDER_CHANGE_LOG_DTN", "DC_TASK_ORDER_4Q", 0.47, "Partial match on \'TASK_ORDER\'"]', '']
# Finish process: 133: [CBS_DC_TASK_ORDER_DTN]: ['["CBS_DC_TASK_ORDER_DTN", "DC_TASK_ORDER_4Q", 0.76, "Partial match on \'TASK_ORDER\'"]', '']
# Finish process: 134: [CBS_DESTCODE_DTN]: ['["CBS_DESTCODE_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 135: [CBS_DUNNING_GROUP_DTN]: ['["CBS_DUNNING_GROUP_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 136: [CBS_EVENTSTORE_SU_DTN]: ['["CBS_EVENTSTORE_SU_DTN", "EF_RC_EVENT_STORE", 0.54, "Partial match on \'EVENT_STORE\'"]', '']
# Finish process: 137: [CBS_FEEID_DTN]: ['["CBS_FEEID_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 138: [CBS_GRPHISLOG_DTN]: ['["CBS_GRPHISLOG_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 139: [CBS_INVOICE_SUMMARY]: ['["CBS_INVOICE_SUMMARY", "AR_INVOICE", 0.67, "Partial match on \'INVOICE\'"]', '["CBS_INVOICE_SUMMARY", "AR_INVOICE_BO", 0.62, "Partial match on \'INVOICE\'"]', '["CBS_INVOICE_SUMMARY", "AR_INVOICE_DETAIL", 0.73, "Partial match on \'INVOICE\'"]', '["CBS_INVOICE_SUMMARY", "BILL_INVOICE_BO", 0.73, "Partial match on \'INVOICE\'"]', '']
# Finish process: 140: [CBS_LOCTRANSLATE_DTN]: ['["CBS_LOCTRANSLATE_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 141: [CBS_MMSSPECIALLIST_DTN]: ['["CBS_MMSSPECIALLIST_DTN", "E_SPEC_NUMBER_MMS", 0.48, "Partial match on \'SPEC\'"]', '']
# Finish process: 142: [CBS_NEW_DUNNING_GROUP_DTN]: ['["CBS_NEW_DUNNING_GROUP_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 143: [CBS_NP_PREFIX_INFO_DTN]: ['["CBS_NP_PREFIX_INFO_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 144: [CBS_NUMSERVICE_DTN]: ['["CBS_NUMSERVICE_DTN", "EF_GPRS_SERVICE", 0.36, "Partial match on \'SERVICE\'"]', '']
# Finish process: 145: [CBS_OCS_BAL2VALIDTY_DTN]: ['["CBS_OCS_BAL2VALIDTY_DTN", "CM_BALANCE_LOG", 0.46, "Partial match on \'BALANCE\'"]', '["CBS_OCS_BAL2VALIDTY_DTN", "CM_ACCT_BALANCE", 0.46, "Partial match on \'BALANCE\'"]', '["CBS_OCS_BAL2VALIDTY_DTN", "CM_BALANCE_TYPE", 0.46, "Partial match on \'BALANCE\'"]', '']
# Finish process: 146: [CBS_OCS_CARDRCHGRWD_DTN]: ['["CBS_OCS_CARDRCHGRWD_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 147: [CBS_OCS_CASHRCHGRWD_DTN]: ['["CBS_OCS_CASHRCHGRWD_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 148: [CBS_OCS_CELLIDTOHZ_DTN]: ['["CBS_OCS_CELLIDTOHZ_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 149: [CBS_OCS_COMMUNITYSET_DTN]: ['["CBS_OCS_COMMUNITYSET_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 150: [CBS_OCS_COMMUNITYTYPE_DTN]: ['["CBS_OCS_COMMUNITYTYPE_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 151: [CBS_OCS_CONTTARIFF_DTN]: ['["CBS_OCS_CONTTARIFF_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 152: [CBS_OCS_CREDITSERVICE_DTN]: ['["CBS_OCS_CREDITSERVICE_DTN", "CM_CREDIT_LIMIT", 0.67, "Partial match on \'CREDIT\'"]', '["CBS_OCS_CREDITSERVICE_DTN", "CM_CREDIT_LIMIT_ACCM", 0.57, "Partial match on \'CREDIT\'"]', '["CBS_OCS_CREDITSERVICE_DTN", "CM_CREDIT_LIMIT_VALUE", 0.53, "Partial match on \'CREDIT\'"]', '["CBS_OCS_CREDITSERVICE_DTN", "PE_CREDIT_LIMIT_TYPE", 0.5, "Partial match on \'CREDIT\'"]', '["CBS_OCS_CREDITSERVICE_DTN", "EF_GPRS_SERVICE", 0.5, "Partial match on \'SERVICE\'"]', '["CBS_OCS_CREDITSERVICE_DTN", "AR_CREDIT_BALANCE", 0.5, "Partial match on \'CREDIT\'"]', '']
# Finish process: 153: [CBS_OCS_FIRSTACTREWARD_DTN]: ['["CBS_OCS_FIRSTACTREWARD_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 154: [CBS_OCS_HOMEZONE_DTN]: ['["CBS_OCS_HOMEZONE_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 155: [CBS_OCS_LOAN_DTN]: ['["CBS_OCS_LOAN_DTN", "E_LOAN_AUTH", 0.53, "Partial match on \'LOAN\'"]', '["CBS_OCS_LOAN_DTN", "RB_PPS_LOAN_INFO", 0.53, "Partial match on \'LOAN\'"]', '["CBS_OCS_LOAN_DTN", "RB_PPS_LOAN_LOG", 0.53, "Partial match on \'LOAN\'"]', '["CBS_OCS_LOAN_DTN", "E_PE_LOAN_CONFIG", 0.53, "Partial match on \'LOAN\'"]', '']
# Finish process: 156: [CBS_OCS_MCCMNCMAP_DTN]: ['["CBS_OCS_MCCMNCMAP_DTN", "SD_MNC_TRANSLATE", 0.56, "Partial match on \'MNC\'"]', '']
# Finish process: 157: [CBS_OCS_ONEOFFFEETREE_DTN]: ['["CBS_OCS_ONEOFFFEETREE_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 158: [CBS_OCS_SPECIALNUMBER_DTN]: ['["CBS_OCS_SPECIALNUMBER_DTN", "E_SPEC_NUMBER_GPRS", 0.56, "Partial match on \'SPEC\'"]', '["CBS_OCS_SPECIALNUMBER_DTN", "E_SPEC_NUMBER_MMS", 0.56, "Partial match on \'SPEC\'"]', '["CBS_OCS_SPECIALNUMBER_DTN", "E_SPEC_NUMBER_SMS", 0.56, "Partial match on \'SPEC\'"]', '["CBS_OCS_SPECIALNUMBER_DTN", "E_SPEC_NUMBER_VOICE", 0.56, "Partial match on \'SPEC\'"]', '["CBS_OCS_SPECIALNUMBER_DTN", "SD_SPEC_PREFIX", 0.5, "Partial match on \'SPEC\'"]', '']
# Finish process: 159: [CBS_OCS_SUBDEBIT_DTN]: ['["CBS_OCS_SUBDEBIT_DTN", "BC_SUB_DFT_ACCT", 0.38, "Partial match on \'SUB\'"]', '["CBS_OCS_SUBDEBIT_DTN", "BC_SUB_GROUP", 0.38, "Partial match on \'SUB\'"]', '["CBS_OCS_SUBDEBIT_DTN", "BC_SUB_IDEN", 0.38, "Partial match on \'SUB\'"]', '["CBS_OCS_SUBDEBIT_DTN", "BC_SUB_PROP", 0.38, "Partial match on \'SUB\'"]', '["CBS_OCS_SUBDEBIT_DTN", "BC_SUB_BRAND", 0.38, "Partial match on \'SUB\'"]', '["CBS_OCS_SUBDEBIT_DTN", "BC_SUB_EXTINFO", 0.38, "Partial match on \'SUB\'"]', '["CBS_OCS_SUBDEBIT_DTN", "BC_SUBSCRIBER", 0.35, "Partial match on \'SUB\'"]', '']
# Finish process: 160: [CBS_OCS_SUBLOANINFO_DTN]: ['["CBS_OCS_SUBLOANINFO_DTN", "E_LOAN_AUTH", 0.46, "Partial match on \'LOAN\'"]', '["CBS_OCS_SUBLOANINFO_DTN", "RB_PPS_LOAN_INFO", 0.46, "Partial match on \'LOAN\'"]', '["CBS_OCS_SUBLOANINFO_DTN", "RB_PPS_LOAN_LOG", 0.46, "Partial match on \'LOAN\'"]', '["CBS_OCS_SUBLOANINFO_DTN", "E_PE_LOAN_CONFIG", 0.46, "Partial match on \'LOAN\'"]', '']
# Finish process: 161: [CBS_OCS_SUBSBDGTCTRL_DTN]: ['["CBS_OCS_SUBSBDGTCTRL_DTN", "BC_SUB_DFT_ACCT", 0.38, "Partial match on \'SUB\'"]', '["CBS_OCS_SUBSBDGTCTRL_DTN", "BC_SUB_GROUP", 0.38, "Partial match on \'SUB\'"]', '["CBS_OCS_SUBSBDGTCTRL_DTN", "BC_SUB_IDEN", 0.38, "Partial match on \'SUB\'"]', '["CBS_OCS_SUBSBDGTCTRL_DTN", "BC_SUB_PROP", 0.38, "Partial match on \'SUB\'"]', '["CBS_OCS_SUBSBDGTCTRL_DTN", "BC_SUB_BRAND", 0.38, "Partial match on \'SUB\'"]', '["CBS_OCS_SUBSBDGTCTRL_DTN", "BC_SUB_EXTINFO", 0.38, "Partial match on \'SUB\'"]', '["CBS_OCS_SUBSBDGTCTRL_DTN", "BC_SUBSCRIBER", 0.35, "Partial match on \'SUB\'"]', '']
# Finish process: 162: [CBS_OFFER_CREDIT_DTN]: ['["CBS_OFFER_CREDIT_DTN", "CM_CREDIT_LIMIT", 0.53, "Partial match on \'CREDIT\'"]', '["CBS_OFFER_CREDIT_DTN", "CM_CREDIT_LIMIT_ACCM", 0.46, "Partial match on \'CREDIT\'"]', '["CBS_OFFER_CREDIT_DTN", "CM_CREDIT_LIMIT_VALUE", 0.42, "Partial match on \'CREDIT\'"]', '["CBS_OFFER_CREDIT_DTN", "PE_CREDIT_LIMIT_TYPE", 0.4, "Partial match on \'CREDIT\'"]', '["CBS_OFFER_CREDIT_DTN", "AR_CREDIT_BALANCE", 0.4, "Partial match on \'CREDIT\'"]', '']
# Finish process: 163: [CBS_PAYMENT_METHOD_DTN]: ['["CBS_PAYMENT_METHOD_DTN", "AR_DIC_PAYMENT_METHOD", 0.89, "Partial match on \'PAYMENT_METHOD\'"]', '["CBS_PAYMENT_METHOD_DTN", "BC_PAYMENT_CHANNEL", 0.53, "Partial match on \'PAYMENT\'"]', '["CBS_PAYMENT_METHOD_DTN", "BC_PAYMENT_RELATION", 0.53, "Partial match on \'PAYMENT\'"]', '["CBS_PAYMENT_METHOD_DTN", "AR_PAYMENT", 0.3, "Partial match on \'PAYMENT\'"]', '["CBS_PAYMENT_METHOD_DTN", "AR_PAYMENT_BO", 0.27, "Partial match on \'PAYMENT\'"]', '']
# Finish process: 164: [CBS_PDM_IARTAB_DTN]: ['["CBS_PDM_IARTAB_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 165: [CBS_PDM_IRPTAB_DTN]: ['["CBS_PDM_IRPTAB_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 166: [CBS_PDM_LK_ICP_IR_DTN]: ['["CBS_PDM_LK_ICP_IR_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 167: [CBS_POLICYATTR_DTN]: ['["CBS_POLICYATTR_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 168: [CBS_PRODUCTEXTATTR_DTN]: ['["CBS_PRODUCTEXTATTR_DTN", "BC_PROD_PROP", 0.43, "Partial match on \'PROD\'"]', '["CBS_PRODUCTEXTATTR_DTN", "PM_PRODUCT", 0.4, "Partial match on \'PROD\'"]', '["CBS_PRODUCTEXTATTR_DTN", "BC_PROD_INST", 0.4, "Partial match on \'PROD\'"]', '']
# Finish process: 169: [CBS_PROVINCE_DTN]: ['["CBS_PROVINCE_DTN", "No Match", 0, "No reason"]', '']
# Exception in thread Thread-343 (_asyncio_thread_main):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/httpx/_transports/default.py", line 101, in map_httpcore_exceptions
#     yield
#   File "/opt/conda/lib/python3.11/site-packages/httpx/_transports/default.py", line 394, in handle_async_request
#     resp = await self._pool.handle_async_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/httpcore/_async/connection_pool.py", line 256, in handle_async_request
#     raise exc from None
#   File "/opt/conda/lib/python3.11/site-packages/httpcore/_async/connection_pool.py", line 236, in handle_async_request
#     response = await connection.handle_async_request(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/httpcore/_async/connection.py", line 101, in handle_async_request
#     raise exc
#   File "/opt/conda/lib/python3.11/site-packages/httpcore/_async/connection.py", line 78, in handle_async_request
#     stream = await self._connect(request)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/httpcore/_async/connection.py", line 156, in _connect
#     stream = await stream.start_tls(**kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/httpcore/_backends/anyio.py", line 67, in start_tls
#     with map_exceptions(exc_map):
#   File "/opt/conda/lib/python3.11/contextlib.py", line 155, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "/opt/conda/lib/python3.11/site-packages/httpcore/_exceptions.py", line 14, in map_exceptions
#     raise to_exc(exc) from exc
# httpcore.ConnectError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/conda/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.11/site-packages/google/adk/runners.py", line 138, in _asyncio_thread_main
#     asyncio.run(_invoke_run_async())
#   File "/opt/conda/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/asyncio/base_events.py", line 653, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/google/adk/runners.py", line 126, in _invoke_run_async
#     async for event in self.run_async(
#   File "/opt/conda/lib/python3.11/site-packages/google/adk/runners.py", line 197, in run_async
#     async for event in invocation_context.agent.run_async(invocation_context):
#   File "/opt/conda/lib/python3.11/site-packages/google/adk/agents/base_agent.py", line 141, in run_async
#     async for event in self._run_async_impl(ctx):
#   File "/opt/conda/lib/python3.11/site-packages/google/adk/agents/llm_agent.py", line 232, in _run_async_impl
#     async for event in self._llm_flow.run_async(ctx):
#   File "/opt/conda/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 231, in run_async
#     async for event in self._run_one_step_async(invocation_context):
#   File "/opt/conda/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 257, in _run_one_step_async
#     async for llm_response in self._call_llm_async(
#   File "/opt/conda/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 470, in _call_llm_async
#     async for llm_response in llm.generate_content_async(
#   File "/opt/conda/lib/python3.11/site-packages/google/adk/models/google_llm.py", line 140, in generate_content_async
#     response = await self.api_client.aio.models.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/google/genai/models.py", line 6269, in generate_content
#     response = await self._generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/google/genai/models.py", line 5271, in _generate_content
#     response_dict = await self._api_client.async_request(
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/google/genai/_api_client.py", line 760, in async_request
#     result = await self._async_request(http_request=http_request, stream=False)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/google/genai/_api_client.py", line 697, in _async_request
#     response = await self._async_httpx_client.request(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/httpx/_client.py", line 1540, in request
#     return await self.send(request, auth=auth, follow_redirects=follow_redirects)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/httpx/_client.py", line 1629, in send
#     response = await self._send_handling_auth(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/httpx/_client.py", line 1657, in _send_handling_auth
#     response = await self._send_handling_redirects(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/httpx/_client.py", line 1694, in _send_handling_redirects
#     response = await self._send_single_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/httpx/_client.py", line 1730, in _send_single_request
#     response = await transport.handle_async_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/httpx/_transports/default.py", line 393, in handle_async_request
#     with map_httpcore_exceptions():
#   File "/opt/conda/lib/python3.11/contextlib.py", line 155, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "/opt/conda/lib/python3.11/site-packages/httpx/_transports/default.py", line 118, in map_httpcore_exceptions
#     raise mapped_exc(message) from exc
# httpx.ConnectError
# Finish process: 170: [CBS_QUERY_MOVEIN_DTN]: ['["CBS_PROVINCE_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 171: [CBS_QUERY_MOVEOUT_DTN]: ['["CBS_QUERY_MOVEIN_DTNCBS_QUERY_MOVEOUT_DTN", "BC_QUERY_RECORD", 0.46, "Partial match on \'QUERY\'"]', '']
# Finish process: 172: [CBS_RATINGGROUP_DTN]: ['["CBS_RATINGGROUP_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 173: [CBS_REBATEBONUS_DTN]: ['["CBS_REBATEBONUS_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 174: [CBS_REBATEFEESET_DTN]: ['["CBS_REBATEFEESET_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 175: [CBS_SEGMENT_ROUTE_CONFIG_DTN]: ['["CBS_SEGMENT_ROUTE_CONFIG_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 176: [CBS_SMSPECIALLIST_DTN]: ['["CBS_SMSPECIALLIST_DTN", "E_SPEC_NUMBER_SMS", 0.48, "Partial match on \'SPEC\'"]', '']
# Finish process: 177: [CBS_SUBSCRIBER_DYN_DTN]: ['["CBS_SUBSCRIBER_DYN_DTN", "BC_SUBSCRIBER", 0.8, "Partial match on \'SUBSCRIBER\'"]', '']
# Finish process: 178: [CBS_TARIFFID_DTN]: ['["CBS_TARIFFID_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 179: [CBS_TB_ACCT_CONTACT_DTN]: ['["CBS_TB_ACCT_CONTACT_DTN", "BC_ACCT", 0.56, "Partial match on \'ACCT\'"]', '']
# Finish process: 180: [CBS_TB_AREADEF_DTN]: ['["CBS_TB_AREADEF_DTN", "SD_AREA", 0.5, "Partial match on \'AREA\'"]', '']
# Finish process: 181: [CBS_TB_COUNTRYDEF_DTN]: ['["CBS_TB_COUNTRYDEF_DTN", "SD_COUNTRY", 0.73, "Partial match on \'COUNTRY\'"]', '["CBS_TB_COUNTRYDEF_DTN", "SD_COUNTRY_GROUP", 0.6, "Partial match on \'COUNTRY\'"]', '']
# Finish process: 182: [CBS_TB_NETWORKCDDEF_DTN]: ['["CBS_TB_NETWORKCDDEF_DTN", "SD_NETWORK", 0.73, "Partial match on \'NETWORK\'"]', '']
# Finish process: 183: [CBS_TC_ACCOUNT_BALANCE_DTN]: ['["CBS_TC_ACCOUNT_BALANCE_DTN", "AR_ACCOUNT_BALANCE", 0.86, "Partial match on \'ACCOUNT_BALANCE\'"]', '["CBS_TC_ACCOUNT_BALANCE_DTN", "CM_ACCT_BALANCE", 0.73, "Partial match on \'ACCOUNT_BALANCE\'"]', '["CBS_TC_ACCOUNT_BALANCE_DTN", "ACCT_BALANCE_BO", 0.6, "Partial match on \'ACCOUNT_BALANCE\'"]', '']
# Finish process: 184: [CBS_TC_ACCTCREDITUSED_DTN]: ['["CBS_TC_ACCTCREDITUSED_DTN", "BC_ACCT", 0.44, "Partial match on \'ACCT\'"]', '["CBS_TC_ACCTCREDITUSED_DTN", "CM_CREDIT_LIMIT", 0.53, "Partial match on \'CREDIT\'"]', '["CBS_TC_ACCTCREDITUSED_DTN", "CM_CREDIT_LIMIT_ACCM", 0.46, "Partial match on \'CREDIT\'"]', '["CBS_TC_ACCTCREDITUSED_DTN", "CM_CREDIT_LIMIT_VALUE", 0.42, "Partial match on \'CREDIT\'"]', '["CBS_TC_ACCTCREDITUSED_DTN", "PE_CREDIT_LIMIT_TYPE", 0.4, "Partial match on \'CREDIT\'"]', '["CBS_TC_ACCTCREDITUSED_DTN", "AR_CREDIT_BALANCE", 0.4, "Partial match on \'CREDIT\'"]', '']
# Finish process: 185: [CBS_TC_SUBSCREDITUSED_DTN]: ['["CBS_TC_SUBSCREDITUSED_DTN", "BC_SUB_DFT_ACCT", 0.35, "Partial match on \'SUB\'"]', '["CBS_TC_SUBSCREDITUSED_DTN", "BC_SUB_GROUP", 0.35, "Partial match on \'SUB\'"]', '["CBS_TC_SUBSCREDITUSED_DTN", "BC_SUB_IDEN", 0.35, "Partial match on \'SUB\'"]', '["CBS_TC_SUBSCREDITUSED_DTN", "BC_SUB_PROP", 0.35, "Partial match on \'SUB\'"]', '["CBS_TC_SUBSCREDITUSED_DTN", "BC_SUB_BRAND", 0.35, "Partial match on \'SUB\'"]', '["CBS_TC_SUBSCREDITUSED_DTN", "BC_SUB_EXTINFO", 0.35, "Partial match on \'SUB\'"]', '["CBS_TC_SUBSCREDITUSED_DTN", "BC_SUBSCRIBER", 0.33, "Partial match on \'SUB\'"]', '["CBS_TC_SUBSCREDITUSED_DTN", "CM_CREDIT_LIMIT", 0.53, "Partial match on \'CREDIT\'"]', '["CBS_TC_SUBSCREDITUSED_DTN", "CM_CREDIT_LIMIT_ACCM", 0.46, "Partial match on \'CREDIT\'"]', '["CBS_TC_SUBSCREDITUSED_DTN", "CM_CREDIT_LIMIT_VALUE", 0.42, "Partial match on \'CREDIT\'"]', '["CBS_TC_SUBSCREDITUSED_DTN", "PE_CREDIT_LIMIT_TYPE", 0.4, "Partial match on \'CREDIT\'"]', '["CBS_TC_SUBSCREDITUSED_DTN", "AR_CREDIT_BALANCE", 0.4, "Partial match on \'CREDIT\'"]', '']
# Finish process: 186: [CBS_TIMESCHEMA_DTN]: ['["CBS_TIMESCHEMA_DTN", "SYS_CALENDAR_TIME", 0.64, "Partial match on \'TIME\'"]', '["CBS_TIMESCHEMA_DTN", "SYS_TIMEZONE", 0.5, "Partial match on \'TIME\'"]', '["CBS_TIMESCHEMA_DTN", "SYS_DIC_TIMEZONE", 0.44, "Partial match on \'TIME\'"]', '']
# Finish process: 187: [CBS_TRADETYPE_DTN]: ['["CBS_TRADETYPE_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 188: [CBS_TS_CREDIT_DTN]: ['["CBS_TS_CREDIT_DTN", "CM_CREDIT_LIMIT", 0.6, "Partial match on \'CREDIT\'"]', '["CBS_TS_CREDIT_DTN", "CM_CREDIT_LIMIT_ACCM", 0.5, "Partial match on \'CREDIT\'"]', '["CBS_TS_CREDIT_DTN", "CM_CREDIT_LIMIT_VALUE", 0.46, "Partial match on \'CREDIT\'"]', '["CBS_TS_CREDIT_DTN", "PE_CREDIT_LIMIT_TYPE", 0.43, "Partial match on \'CREDIT\'"]', '["CBS_TS_CREDIT_DTN", "AR_CREDIT_BALANCE", 0.43, "Partial match on \'CREDIT\'"]', '']
# Finish process: 189: [CBS_TS_INTERNUMHEAD_DTN]: ['["CBS_TS_INTERNUMHEAD_DTN", "SD_INTER_NUM_HEAD", 0.8, "Partial match on \'INTER_NUM_HEAD\'"]', '']
# Finish process: 190: [CBS_TS_MSCTRANSLATE_DTN]: ['["CBS_TS_MSCTRANSLATE_DTN", "SD_MSC_TRANSLATE", 0.76, "Partial match on \'MSC_TRANSLATE\'"]', '']
# Finish process: 191: [CBS_TS_NATIVENUMHED_DTN]: ['["CBS_TS_NATIVENUMHED_DTN", "SD_NATIVE_NUM_HEAD", 0.76, "Partial match on \'NATIVE_NUM_HEAD\'"]', '']
# Finish process: 192: [CBS_TS_PODETAIL_DTN]: ['["CBS_TS_PODETAIL_DTN", "AR_INVOICE_DETAIL", 0.4, "Partial match on \'DETAIL\'"]', '["CBS_TS_PODETAIL_DTN", "AR_APPLY_DETAIL", 0.44, "Partial match on \'DETAIL\'"]', '["CBS_TS_PODETAIL_DTN", "AR_LOG_TRX_DETAIL", 0.4, "Partial match on \'DETAIL\'"]', '["CBS_TS_PODETAIL_DTN", "AR_REQUEST_DETAIL", 0.44, "Partial match on \'DETAIL\'"]', '["CBS_TS_PODETAIL_DTN", "AR_TAX_DETAIL", 0.36, "Partial match on \'DETAIL\'"]', '["CBS_TS_PODETAIL_DTN", "CM_SS_DETAIL_DEFINITON", 0.36, "Partial match on \'DETAIL\'"]', '["CBS_TS_PODETAIL_DTN", "DC_PA_DETAIL", 0.48, "Partial match on \'DETAIL\'"]', '']
# Finish process: 193: [CBS_TS_POEXTATTR_DTN]: ['["CBS_TS_POEXTATTR_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 194: [CBS_TS_POINSTANCE_DTN]: ['["CBS_TS_POINSTANCE_DTN", "BC_OFFERING_INST", 0.42, "Partial match on \'INST\'"]', '["CBS_TS_POINSTANCE_DTN", "OFFERING_INST_BO", 0.42, "Partial match on \'INST\'"]', '["CBS_TS_POINSTANCE_DTN", "BC_PROD_INST", 0.38, "Partial match on \'INST\'"]', '["CBS_TS_POINSTANCE_DTN", "DC_HOLD_INSTANCE", 0.35, "Partial match on \'INST\'"]', '']
# Finish process: 195: [CBS_TS_POINSTATTR_DTN]: ['["CBS_TS_POINSTATTR_DTN", "BC_OFFERING_INST", 0.46, "Partial match on \'INST\'"]', '["CBS_TS_POINSTATTR_DTN", "OFFERING_INST_BO", 0.46, "Partial match on \'INST\'"]', '["CBS_TS_POINSTATTR_DTN", "BC_PROD_INST", 0.42, "Partial match on \'INST\'"]', '["CBS_TS_POINSTATTR_DTN", "DC_HOLD_INSTANCE", 0.38, "Partial match on \'INST\'"]', '']
# Finish process: 196: [CBS_TS_PRODPRICEPLN_DTN]: ['["CBS_TS_PRODPRICEPLN_DTN", "PM_PRODUCT", 0.43, "Partial match on \'PROD\'"]', '["CBS_TS_PRODPRICEPLN_DTN", "BC_PROD_INST", 0.4, "Partial match on \'PROD\'"]', '']
# Finish process: 197: [CBS_TS_PRODUCTOFFER_DTN]: ['["CBS_TS_PRODUCTOFFER_DTN", "PM_PRODUCT", 0.43, "Partial match on \'PROD\'"]', '["CBS_TS_PRODUCTOFFER_DTN", "BC_PROD_INST", 0.4, "Partial match on \'PROD\'"]', '']
# Finish process: 198: [CBS_TS_PRODUCTORDER_DTN]: ['["CBS_TS_PRODUCTORDER_DTN", "DC_TASK_ORDER_4Q", 0.36, "Partial match on \'ORDER\'"]', '']
# Finish process: 199: [CBS_TS_PRODUCTSPEC_DTN]: ['["CBS_TS_PRODUCTSPEC_DTN", "PM_PRODUCT", 0.43, "Partial match on \'PROD\'"]', '["CBS_TS_PRODUCTSPEC_DTN", "BC_PROD_INST", 0.4, "Partial match on \'PROD\'"]', '["CBS_TS_PRODUCTSPEC_DTN", "SD_SPEC_PREFIX", 0.46, "Partial match on \'SPEC\'"]', '["CBS_TS_PRODUCTSPEC_DTN", "E_SPEC_NUMBER_GPRS", 0.43, "Partial match on \'SPEC\'"]', '["CBS_TS_PRODUCTSPEC_DTN", "E_SPEC_NUMBER_MMS", 0.43, "Partial match on \'SPEC\'"]', '["CBS_TS_PRODUCTSPEC_DTN", "E_SPEC_NUMBER_SMS", 0.43, "Partial match on \'SPEC\'"]', '["CBS_TS_PRODUCTSPEC_DTN", "E_SPEC_NUMBER_VOICE", 0.43, "Partial match on \'SPEC\'"]', '']
# Finish process: 200: [CBS_TS_SUBSCREDIT_DTN]: ['["CBS_TS_SUBSCREDIT_DTN", "BC_SUB_DFT_ACCT", 0.35, "Partial match on \'SUB\'"]', '["CBS_TS_SUBSCREDIT_DTN", "BC_SUB_GROUP", 0.35, "Partial match on \'SUB\'"]', '["CBS_TS_SUBSCREDIT_DTN", "BC_SUB_IDEN", 0.35, "Partial match on \'SUB\'"]', '["CBS_TS_SUBSCREDIT_DTN", "BC_SUB_PROP", 0.35, "Partial match on \'SUB\'"]', '["CBS_TS_SUBSCREDIT_DTN", "BC_SUB_BRAND", 0.35, "Partial match on \'SUB\'"]', '["CBS_TS_SUBSCREDIT_DTN", "BC_SUB_EXTINFO", 0.35, "Partial match on \'SUB\'"]', '["CBS_TS_SUBSCREDIT_DTN", "BC_SUBSCRIBER", 0.33, "Partial match on \'SUB\'"]', '["CBS_TS_SUBSCREDIT_DTN", "CM_CREDIT_LIMIT", 0.6, "Partial match on \'CREDIT\'"]', '["CBS_TS_SUBSCREDIT_DTN", "CM_CREDIT_LIMIT_ACCM", 0.5, "Partial match on \'CREDIT\'"]', '["CBS_TS_SUBSCREDIT_DTN", "CM_CREDIT_LIMIT_VALUE", 0.46, "Partial match on \'CREDIT\'"]', '["CBS_TS_SUBSCREDIT_DTN", "PE_CREDIT_LIMIT_TYPE", 0.43, "Partial match on \'CREDIT\'"]', '["CBS_TS_SUBSCREDIT_DTN", "AR_CREDIT_BALANCE", 0.43, "Partial match on \'CREDIT\'"]', '']
# Finish process: 201: [CBS_TS_TIERRENTLIST_DTN]: ['["CBS_TS_TIERRENTLIST_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 202: [CDR_CLR_DTN]: ['["CDR_CLR_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 203: [CDR_CONTENT_DTN]: ['["CDR_CONTENT_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 204: [CDR_DATA_DTN]: ['["CDR_DATA_DTN", "SD_AREA", 0.3, "Partial match on \'DATA\'"]', '']
# Finish process: 205: [CDR_F_MON_DTN]: ['["CDR_F_MON_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 206: [CDR_FILL_FEE_DTN]: ['["CDR_FILL_FEE_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 207: [CDR_GFT_DTN]: ['["CDR_GFT_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 208: [CDR_MGR_DTN]: ['["CDR_MGR_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 209: [CDR_MMS_DTN]: ['["CDR_MMS_DTN", "E_SPEC_NUMBER_MMS", 0.53, "Partial match on \'MMS\'"]', '']
# Finish process: 210: [CDR_MON_DTN]: ['["CDR_MON_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 211: [CDR_OCONTENT_DTN]: ['["CDR_OCONTENT_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 212: [CDR_ODATA_DTN]: ['["CDR_ODATA_DTN", "SD_AREA", 0.33, "Partial match on \'DATA\'"]', '']
# Finish process: 213: [CDR_OFREEUACC_DTN]: ['["CDR_OFREEUACC_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 214: [CDR_OGFT_DTN]: ['["CDR_OGFT_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 215: [CDR_OMGR_DTN]: ['["CDR_OMGR_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 216: [CDR_OMMS_DTN]: ['["CDR_OMMS_DTN", "E_SPEC_NUMBER_MMS", 0.56, "Partial match on \'MMS\'"]', '']
# Finish process: 217: [CDR_OMON_DTN]: ['["CDR_OMON_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 218: [CDR_OREC_DTN]: ['["CDR_OREC_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 219: [CDR_OSMS_DTN]: ['["CDR_OSMS_DTN", "E_SPEC_NUMBER_SMS", 0.56, "Partial match on \'SMS\'"]', '']
# Finish process: 220: [CDR_OSYLOWBAL_DTN]: ['["CDR_OSYLOWBAL_DTN", "CM_BALANCE_LOG", 0.31, "Partial match on \'BAL\'"]', '["CDR_OSYLOWBAL_DTN", "CM_ACCT_BALANCE", 0.31, "Partial match on \'BAL\'"]', '["CDR_OSYLOWBAL_DTN", "CM_BALANCE_TYPE", 0.31, "Partial match on \'BAL\'"]', '']
# Finish process: 221: [CDR_REC_DTN]: ['["CDR_REC_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 222: [CDR_RETURN_DTN]: ['["CDR_RETURN_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 223: [CDR_SMS_DTN]: ['["CDR_SMS_DTN", "E_SPEC_NUMBER_SMS", 0.53, "Partial match on \'SMS\'"]', '']
# Finish process: 224: [CDR_SYLOWBAL_DTN]: ['["CDR_SYLOWBAL_DTN", "CM_BALANCE_LOG", 0.3, "Partial match on \'BAL\'"]', '["CDR_SYLOWBAL_DTN", "CM_ACCT_BALANCE", 0.3, "Partial match on \'BAL\'"]', '["CDR_SYLOWBAL_DTN", "CM_BALANCE_TYPE", 0.3, "Partial match on \'BAL\'"]', '']
# Finish process: 225: [CDR_VOU_DTN]: ['["CDR_VOU_DTN", "No Match", 0, "No reason"]', '']
# Finish process: 226: [SOF_EXPIRED_SUBSCR_DTN]: ['["SOF_EXPIRED_SUBSCR_DTN", "BC_SUBSCRIBER", 0.57, "Partial match on \'SUBSCRIBER\'"]', '']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 60
#      56     print(f"Finish process: {i}: [{feed_word}]: {list_ot_output}")
#      57     i += 1
# ---> 60 final_df = pd.DataFrame(new_df, columns=columns)
#      61 print("### Finish Call AI Agent")
#
# NameError: name 'columns' is not defined

# %%
from io import StringIO

s3 = base_tools.register_datalake()

# Convert DataFrame to CSV in memory
csv_buffer = StringIO()
final_df.to_csv(csv_buffer, index=False)
csv_buffer.seek(0)

# Upload to MinIO
try:
    s3.put_object(
        Bucket='datalake',
        Key='export/final_cbs.csv',
        Body=csv_buffer.getvalue(),
        ContentType='text/csv'
    )
    print(f"✅ Uploaded to datalake/export/final_cbs.csv")
except Exception as e:
    print(f"❌ Failed to upload: {e}")
# Out:
# ✅ Uploaded to datalake/export/final_cbs.csv
